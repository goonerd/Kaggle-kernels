# %%
 # This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
import sqlite3
warnings.filterwarnings('ignore')


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory


database = '../input/database.sqlite'
conn = sqlite3.connect(database)
test_query="select * from Player;"
df_test=pd.read_sql(test_query, conn)
df_test.head()
query="select * from player left join player_attributes using (player_api_id)  group by player_api_id ;"
df=pd.read_sql(query, conn)


# Any results you write to the current directory are saved as output.

# %%
acc=df['acceleration']
speed=df['sprint_speed']
data=pd.concat([acc,speed],axis=1)

data.plot.scatter(x='sprint_speed',y='acceleration',xlim=(0,100),ylim=(0,100))

# %%
rating=df['overall_rating']
rating.head()
fk=df['free_kick_accuracy']
fk.head()

data=pd.concat([rating,fk],axis=1)
data.head()
data.plot.scatter(x='free_kick_accuracy',y='overall_rating',xlim=(0,100),ylim=(40,100))

# %%
finishing=df['finishing']
finishing.head()
data=pd.concat([rating,finishing],axis=1)
data.plot.scatter(x='finishing',y='overall_rating',xlim=(0,100),ylim=(40,100))

# %%
height=df['height']
height.head()
data=pd.concat([rating,height],axis=1)
data.plot.scatter(x='height',y='overall_rating',xlim=(150,220),ylim=(40,100))

# %%
weight=df['weight']
data=pd.concat([rating,weight],axis=1)
data.plot.scatter(x='weight',y='overall_rating')

# %%
passing=df['short_passing']
data=pd.concat([rating,passing],axis=1)
data.plot.scatter(x='short_passing',y='overall_rating')

# %%
control=df['ball_control']
data=pd.concat([control,rating],axis=1)
data.plot.scatter(x='ball_control',y='overall_rating')
